# %% [markdown]
# <h2>lasVegas.csv Business Processing

# %% [markdown]
# <h4>Import Statements

# %%
import pandas as pd
import json
import numpy as np
import ast
from tqdm import tqdm_notebook

# %% [markdown]
# <h4>Reading lasVegas.csv into Pandas Dataframe df

# %%
df=pd.DataFrame.from_csv('/home/rim/INF-Project/preprocessed_lasVegas.csv')
df.shape
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
# (8808, 15)

# %%
#Reading from yelp json
#df=pd.read_json('/home/rim/Desktop/Yelp dataset/yelp_academic_dataset_business.json',lines=True)
#df.shape

# %%
#df.columns.values
#df.loc[df['state'] == 'CA']

# %% [markdown]
# <h4>Select required columns and rename columns to standard names

# %%
df=df[['business_id','name','neighborhood','address','city','state','postal_code','stars','review_count','attributes']]
df.columns=['BusinessId',"RestaurantName",'Neighborhood',"Address",'City','State','Zip','Stars','ReviewCount','attributes']
df.columns.values
# Out:
# array(['BusinessId', 'RestaurantName', 'Neighborhood', 'Address', 'City',
#        'State', 'Zip', 'Stars', 'ReviewCount', 'attributes'], dtype=object)

# %% [markdown]
# <h4>Divide df into 2 parts - attributes and the rest

# %%
df_1=df[['BusinessId',"RestaurantName",'Neighborhood',"Address",'City','State','Zip','Stars','ReviewCount']]
df_2=df[['attributes']]

# %% [markdown]
# <h4> Replace blank with ''

# %%
df_1.fillna('', inplace=True)
df_1
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
#                     BusinessId                          RestaurantName  \
# 19      vJIuDBdu01vCA8y1fwR1OQ                              CakesbyToi
# 32      kgffcoxT6BQp-gJ-UQ7Czw                                  Subway
# 33      0jtRI7hVMpQHpUVtUy4ITw                  Omelet House Summerlin
# 61      JJEx5wIqs9iGGATOagE8Sg                Baja Fresh Mexican Grill
# 83      coVhQD_EAnCof_a8sGM03g                         Provence Bakery
# 141     zhxnD7J5_sCrKSw5cwI9dQ               Popeyes Louisiana Kitchen
# 143     2kWrSFkIes_d2BMg4YrRtA                               Pizza Hut
# 145     6llKs7K_tn8ChXcIM-oTvg                            Sansei Japan
# 161     nqnYDW_FMwuTejAPNEOhqA       Seasonal Adventures Pumpkin Patch
# 197     YV9GVfmDSDM7HSV0jVdTOA                           El Pollo Loco
# 203     F7OsiFk9aLZtqZczA84xpw               Popeyes Louisiana Kitchen
# 249     XeDLyY2a7nZ3IEY4RYslXA                 Chicago Brewing Company
# 257     MDVbJicJvqaO4WGx0vEabQ                                 Chili's
# 271     AAcaGYggq4RBbFdEueB2qw                    Green Valley Grocery
# 277     Zh6fxrqsKqdSVmTK3roxBQ             Triumph Property Management
# 279     sOkQ2Y1-D8h18oN5NgxuLg  Haddies Car Wash and Convenience store
# 307     OyJDaAAMr220qkZsovCARQ                               Starbucks
# 325     lv5Bnqlt93NnvNJ2oNcQ8Q                  Los Cucos Mexican Cafe
# 391     D1TaFES4phv65RmsM8VCiA                          Domino's Pizza
# 397     vTch8eXerkbaJbmkmYwCEw                      One Six Sky Lounge
# 497     glkEaoxbewiSMBiXs945JA                             800 Degrees
# 503     3TX-5V6MuGPKnZv6gW1nsg                                Cardenas
# 539     lYCeqldIiOggsbByH3RRhw                             Metro Pizza
# 541     tA1oBX1q6Aqj8UG3y-SqTA                                IT'SUGAR
# 605     juuv0QPE_MfnVjevQTpCDg                       Manhattan Streets
# 630     DbK9fyJq4O4zfT1jv6JOhw                 Pam Real Thai Las Vegas
# 758     PChG1Dm0A6AXIXkXGVK8Fw                              Sasa Sushi
# 764     owxcYAUca_6K6BAUX4V48w                           D'Pinoy Joint
# 912     WSGHEQdcdbBWXDpna99EiQ                        Teriyaki Madness
# 949     0aDCv4zPhzy7RklHDrnKQg                          Lucie's Lounge
# ...                        ...                                     ...
# 187929  diFj7LtBvNcgMy4Pb4_m0g   ROYCE' Las Vegas at Fashion Show Mall
# 188066  6xgcHeLad-VaoTIQewK84A                         N9NE Steakhouse
# 188067  _Jt9CLSL2sqF-yCNel9D-g                             Casa Robles
# 188103  5FgLuegzxBvRFw5dTuETEw                             The Chelsea
# 188155  dTsyfvRfN-zFdsgIDuQllQ                           Alder & Birch
# 188156  OaHfq01gm8PTYkJ36k1feg     Michael T's Steaks, Ribs, & Burgers
# 188157  brB2AfUTKumrRNanOZVw4w                             Scarlet Bar
# 188159  ZyTrka-HiVb6Ckcl0rDaNA               Popeyes Louisiana Kitchen
# 188254  vodCM302JJ_P9yJt1WuH_w                                Vege-Way
# 188255  YAiHkQAQ9sm23V1CyNT2zQ                     Bogey's Bar & Grill
# 188309  cYwJA2A6I12KNkm2rtXd5g                     Gordon Ramsay BurGR
# 188310  RSPEJeFTKs1BsiVgjHp1WQ                  Spago by Wolfgang Puck
# 188317  YhCh4mAs52COFPNLJUOFWQ                               Tonic Bar
# 188318  SUTTl_NCJb5JYdlMBnuVxg                       Wetzel's Pretzels
# 188319  swtA5YoSGm0V5esQuDm2NQ                                  Social
# 188344  YC1FXuG7IQneHnhbHT0XcQ                           The Lobby Bar
# 188380  WEPqQjRGviPyCKEmPhALSw                      The Coachman's Inn
# 188417  ZVetFAAt0_j0tEqiakpecA                         Jack in the Box
# 188418  WUswpeAjbiww_xkSS8jTEA          Pupusas La Familiar Restaurant
# 188445  5iAFiMPfitcYDMeII5_dnQ                           Auntie Anne's
# 188447  qtc1YZix_5lHBJTZq7DOpA                               Zeffirino
# 188448  PDIh1lVtKlUqPJROXYJQvQ                                     FIX
# 188450  TEpHybMZew9kKadvseEbEQ                             Kung Fu Tea
# 188488  g62SlImzhs6_1t-knPjd8w    Red Square Restaurant & Vodka Lounge
# 188497  UNsvHecpu_sPBeQGFxSCUA             Monthathong Thai Restaurant
# 188520  8w2Mzdz-JKy3qOpndK1Wqw                                  Subway
# 188547  qjyOjCHG9lOkZnAa8jIQ1g                           Master Donuts
# 188567  0zGeYN8ReYwVj27U7EHOJA                           American Cafe
# 188570  K9ukZjvXhDjQZnrrOPqKSw                   Montecristo Cigar Bar
# 188572  GdGXb80QKTMRP7AdPHDnuw                     Breeze Daiquiri Bar
#
#          Neighborhood                                            Address  \
# 19                                 3940 Martin Luther King Blvd, Ste 101
# 32          Summerlin                                2255 N Rampart Blvd
# 33          Summerlin                                2227 N Rampart Blvd
# 61         Centennial                               7930 W Tropical Pkwy
# 83          Chinatown                            5115 Spring Mountain Rd
# 141           Sunrise                                  4505 E Bonanza Rd
# 143           Sunrise                         560 N. Nellis Blvd, Ste E1
# 145          Eastside                               3480 S Maryland Pkwy
# 161        Centennial                     6400 SE Centennial Center Blvd
# 197         Southeast                               2505 E Tropicana Ave
# 203         Southeast                               4910 S Maryland Pkwy
# 249          Westside                              2201 S Fort Apache Rd
# 257         Southeast                              7530 S Las Vegas Blvd
# 271     Spring Valley                                  6875 W Russell Rd
# 277         Summerlin                      911 North Buffalo Dr, Ste 202
# 279     Spring Valley                              9920 West Flamingo Rd
# 307                                             751 N Rancho Dr, Ste 110
# 325     Spring Valley                          7315 Arroyo Crossing Pkwy
# 391         Summerlin                        8532 Del Webb Blvd, Ste 116
# 397                                                     5255 Boulder Hwy
# 497         The Strip                              3770 Las Vegas Blvd S
# 503           Sunrise                                  4421 E Bonanza Rd
# 539         Southeast                             5757 Wayne Newton Blvd
# 541         Southeast                     6587 Las Vegas Blvd S, Ste 176
# 605         The Strip                     3717 S Las Vegas Blvd, Ste 210
# 630         Chinatown                                3650 S Decatur Blvd
# 758         Northwest                       7450 W Cheyenne Ave, Ste 118
# 764         Southeast                     7680 S Las Vegas Blvd, Ste 202
# 912                                                  7481 West Lake Mead
# 949           Sunrise                      3935 E Charleston Blvd, Ste A
# ...               ...                                                ...
# 187929      The Strip                     3200 S Las Vegas Blvd, Ste 600
# 188066                                                4321 W Flamingo Rd
# 188067                                                5900 W Flamingo Rd
# 188103      The Strip                              3708 Las Vegas Blvd S
# 188155                                              4500 W Tropicana Ave
# 188156      Southwest                             7315 W Warm Springs Rd
# 188157                                                4321 W Flamingo Rd
# 188159                                               4001 S Decatur Blvd
# 188254      Southwest                                  7790 S Jones Blvd
# 188255      Northwest                                      7770 W Ann Rd
# 188309      The Strip                              3667 Las Vegas Blvd S
# 188310      The Strip                              3600 S Las Vegas Blvd
# 188317                                             4321 West Flamingo Rd
# 188318                                             3700 Flamingo, Ste 18
# 188319                                                4321 W Flamingo Rd
# 188344      The Strip                                 75 East Harmon Ave
# 188380       Eastside                                 3240 S Eastern Ave
# 188417       Eastside                               2970 E Desert Inn Rd
# 188418       Eastside                               4524 E Tropicana Ave
# 188445      The Strip                  3200 S Las Vegas Blvd, Space 1090
# 188447      The Strip      3377 Las Vegas Blvd S, Ste 2095, The Venetian
# 188448      The Strip          Bellagio Las Vegas, 3600 S Las Vegas Blvd
# 188450      The Strip  3200 S Las Vegas Blvd, Space 7500, Fl 3rd, Sou...
# 188488      The Strip                              3950 Las Vegas Blvd S
# 188497      Southeast                                    5075 S Pecos Rd
# 188520       Eastside                               3519 S Maryland Pkwy
# 188547       Eastside                       2300 E Desert Inn Rd, Ste 11
# 188567      The Strip                              3049 Las Vegas Blvd S
# 188570      The Strip  Caesars Palace Las Vegas Hotel And Casino, 357...
# 188572      The Strip                              3475 S Las Vegas Blvd
#
#              City State    Zip  Stars  ReviewCount
# 19      Las Vegas    NV  89106    1.5            3
# 32      Las Vegas    NV  89128    2.5           13
# 33      Las Vegas    NV  89128    4.0          242
# 61      Las Vegas    NV  89149    2.0            4
# 83      Las Vegas    NV  89146    2.0            8
# 141     Las Vegas    NV  89110    1.5           16
# 143     Las Vegas    NV  89110    2.5           19
# 145     Las Vegas    NV  89169    4.5            3
# 161     Las Vegas    NV  89149    3.0           11
# 197     Las Vegas    NV  89121    3.0           34
# 203     Las Vegas    NV  89119    2.0           56
# 249     Las Vegas    NV  89117    3.5          446
# 257     Las Vegas    NV  89123    3.0          230
# 271     Las Vegas    NV  89118    5.0            3
# 277     Las Vegas    NV  89128    1.5           66
# 279     Las Vegas    NV  89147    5.0            9
# 307     Las Vegas    NV  89106    3.0           49
# 325     Las Vegas    NV  89113    4.0          313
# 391     Las Vegas    NV  89134    2.5           27
# 397     Las Vegas    NV  89122    3.5           10
# 497     Las Vegas    NV  89109    3.5          466
# 503     Las Vegas    NV  89110    4.0           55
# 539     Las Vegas    NV  89119    2.5           21
# 541     Las Vegas    NV  89119    4.0           59
# 605     Las Vegas    NV  89109    3.5            7
# 630     Las Vegas    NV  89103    4.0           77
# 758     Las Vegas    NV  89129    4.0          509
# 764     Las Vegas    NV  89123    4.5          134
# 912     Las Vegas    NV  89128    3.5          119
# 949     Las Vegas    NV  89104    4.0           10
# ...           ...   ...    ...    ...          ...
# 187929  Las Vegas    NV  89109    5.0            4
# 188066  Las Vegas    NV  89103    4.0          834
# 188067  Las Vegas    NV  89103    5.0           24
# 188103  Las Vegas    NV  89109    4.0           97
# 188155  Las Vegas    NV  89103    4.5          133
# 188156  Las Vegas    NV  89113    4.0           97
# 188157  Las Vegas    NV  89103    4.0           16
# 188159  Las Vegas    NV  89103    3.5           15
# 188254  Las Vegas    NV  89139    4.0          415
# 188255  Las Vegas    NV  89149    3.0           19
# 188309  Las Vegas    NV  89109    4.0         5472
# 188310  Las Vegas    NV  89109    4.0           17
# 188317  Las Vegas    NV  89103    3.5            3
# 188318  Las Vegas    NV  89103    3.5           15
# 188319  Las Vegas    NV  89103    4.0           19
# 188344  Las Vegas    NV  89109    4.0            6
# 188380  Las Vegas    NV  89169    4.0           20
# 188417  Las Vegas    NV  89121    2.5           15
# 188418  Las Vegas    NV  89121    3.0           41
# 188445  Las Vegas    NV  89109    3.0           22
# 188447  Las Vegas    NV  89109    3.5          402
# 188448  Las Vegas    NV  89109    3.5          636
# 188450  Las Vegas    NV  89109    4.0           66
# 188488  Las Vegas    NV  89119    4.0          619
# 188497  Las Vegas    NV  89120    4.5            5
# 188520  Las Vegas    NV  89169    2.0           12
# 188547  Las Vegas    NV  89169    4.5           86
# 188567  Las Vegas    NV  89109    2.5            7
# 188570  Las Vegas    NV  89109    4.5          108
# 188572  Las Vegas    NV  89109    4.0            5
#
# [8808 rows x 9 columns]

# %% [markdown]
# <h4> Replace None or NA attributes with {}

# %%
df_2.replace('None','{}', inplace=True)
df_2.fillna('{}', inplace=True)
df_2
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:3798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
#                                                attributes
# 19      {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 32      {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 33      {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 61      {'HasTV': 'False', 'RestaurantsReservations': ...
# 83      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 141     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 143     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 145     {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 161     {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 197     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 203     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 249     {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 257     {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 271     {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 277     {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 279     {'Ambience': "{'romantic': False, 'intimate': ...
# 307     {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 325     {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 391     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 397     {'Alcohol': 'full_bar', 'BestNights': "{'monda...
# 497     {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 503     {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 539     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 541     {'BikeParking': 'True', 'BusinessAcceptsBitcoi...
# 605     {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 630     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 758     {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 764     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 912     {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 949     {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# ...                                                   ...
# 187929  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 188066  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188067  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188103  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 188155  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188156  {'Alcohol': 'full_bar', 'BestNights': "{'monda...
# 188157  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188159  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188254  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188255  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188309  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188310  {'Ambience': "{'romantic': False, 'intimate': ...
# 188317  {'Alcohol': 'full_bar', 'BusinessAcceptsCredit...
# 188318  {'BikeParking': 'False', 'BusinessAcceptsBitco...
# 188319  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188344  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 188380  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188417  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188418  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188445  {'Ambience': "{'romantic': False, 'intimate': ...
# 188447  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188448  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188450  {'BikeParking': 'True', 'BusinessAcceptsBitcoi...
# 188488  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188497  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188520  {'Alcohol': 'none', 'Ambience': "{'romantic': ...
# 188547  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 188567  {'Ambience': "{'romantic': False, 'intimate': ...
# 188570  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
# 188572  {'Alcohol': 'full_bar', 'Ambience': "{'romanti...
#
# [8808 rows x 1 columns]

# %% [markdown]
# <h4> Making a new dataframe out of attributes dictionary

# %%
cols=['BikeParking','BusinessAcceptsCreditCards','BusinessParking','GoodForKids','HasTV','NoiseLevel','OutdoorSeating','RestaurantsAttire','RestaurantsDelivery','RestaurantsGoodForGroups','RestaurantsPriceRange2','RestaurantsReservations','RestaurantsTakeOut']

df_3=pd.DataFrame(columns=cols)

for index, row in tqdm_notebook(df_2.iterrows()):
    string=ast.literal_eval(row.attributes)
    df_4=pd.DataFrame.from_dict([string])
    df_3=pd.concat([df_3,df_4], axis=0)
df_3
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    AcceptsInsurance AgesAllowed        Alcohol  \
# 0               NaN         NaN            NaN
# 0               NaN         NaN           none
# 0               NaN         NaN  beer_and_wine
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN           none
# 0               NaN         NaN       full_bar
# 0               NaN         NaN  beer_and_wine
# 0               NaN         NaN            NaN
# 0               NaN         NaN           none
# 0               NaN         NaN            NaN
# 0               NaN         NaN  beer_and_wine
# 0               NaN         NaN           none
# 0               NaN         NaN  beer_and_wine
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN       full_bar
# ..              ...         ...            ...
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN           none
# 0               NaN         NaN           none
# 0               NaN         NaN            NaN
# 0               NaN         NaN            NaN
# 0               NaN         NaN       full_bar
# 0               NaN         NaN       full_bar
#
#                                              Ambience   BYOB  BYOBCorkage  \
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# ..                                                ...    ...          ...
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...  False  yes_corkage
# 0   {'romantic': False, 'intimate': True, 'classy'...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': True, 'classy'...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': True, 'intimate': False, 'classy'...  False  yes_corkage
# 0   {'romantic': False, 'intimate': False, 'classy...  False           no
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...  False  yes_corkage
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0                                                 NaN    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
# 0   {'romantic': False, 'intimate': False, 'classy...    NaN          NaN
#
#                                            BestNights BikeParking  \
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN       False
# 0                                                 NaN       False
# 0                                                 NaN         NaN
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...        True
# 0                                                 NaN       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...        True
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...         NaN
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0                                                 NaN         NaN
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0                                                 NaN        True
# ..                                                ...         ...
# 0                                                 NaN         NaN
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0                                                 NaN         NaN
# 0   {'monday': False, 'tuesday': False, 'friday': ...       False
# 0   {'monday': False, 'tuesday': False, 'friday': ...        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...        True
# 0                                                 NaN       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN       False
# 0   {'monday': False, 'tuesday': False, 'friday': ...        True
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN       False
# 0                                                 NaN       False
# 0   {'monday': False, 'tuesday': False, 'friday': ...       False
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...       False
# 0                                                 NaN        True
# 0                                                 NaN       False
# 0                                                 NaN        True
# 0                                                 NaN        True
# 0   {'monday': False, 'tuesday': False, 'friday': ...       False
# 0                                                 NaN       False
#
#    BusinessAcceptsBitcoin BusinessAcceptsCreditCards  ...   \
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                        NaN  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                   False                      False  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                   False                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# ..                    ...                        ...  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                   False                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                   False                       True  ...
# 0                   False                       True  ...
# 0                   False                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                     NaN                       True  ...
# 0                   False                       True  ...
#
#    RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 0                        NaN               False                      NaN
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN                True                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                      NaN
# 0                        NaN               False                      NaN
# 0                        NaN               False                     True
# 0                        NaN                True                     True
# 0                        NaN                 NaN                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN                True                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                     True
# ..                       ...                 ...                      ...
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                    False
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN                 NaN                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                     True
# 0                        NaN               False                     True
# 0                        NaN                True                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                       True               False                     True
# 0                        NaN                True                     True
# 0                        NaN               False                     True
# 0                        NaN                 NaN                      NaN
# 0                        NaN                True                     True
# 0                        NaN                 NaN                     True
# 0                        NaN                 NaN                    False
#
#    RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 0                     NaN                     NaN                     NaN
# 0                       1                   False                   False
# 0                       2                   False                    True
# 0                     NaN                   False                     NaN
# 0                       1                     NaN                     NaN
# 0                       1                   False                   False
# 0                       2                   False                   False
# 0                       1                   False                     NaN
# 0                     NaN                     NaN                     NaN
# 0                       1                   False                   False
# 0                       1                   False                   False
# 0                       2                    True                    True
# 0                       2                    True                    True
# 0                       2                     NaN                     NaN
# 0                     NaN                     NaN                     NaN
# 0                       2                   False                     NaN
# 0                       1                     NaN                     NaN
# 0                       2                    True                    True
# 0                       2                   False                     NaN
# 0                       1                     NaN                     NaN
# 0                       2                   False                   False
# 0                       1                     NaN                     NaN
# 0                       1                   False                   False
# 0                       2                     NaN                     NaN
# 0                       1                     NaN                   False
# 0                       1                    True                    True
# 0                       2                    True                    True
# 0                       2                    True                    True
# 0                       1                   False                   False
# 0                       1                     NaN                     NaN
# ..                    ...                     ...                     ...
# 0                       2                     NaN                     NaN
# 0                       4                    True                    True
# 0                       2                    True                    True
# 0                     NaN                     NaN                     NaN
# 0                       3                    True                    True
# 0                       2                    True                    True
# 0                       3                     NaN                     NaN
# 0                       1                   False                   False
# 0                       1                   False                   False
# 0                       2                    True                    True
# 0                       2                   False                    True
# 0                       2                    True                     NaN
# 0                       2                   False                     NaN
# 0                       1                     NaN                     NaN
# 0                       2                   False                     NaN
# 0                       2                   False                     NaN
# 0                       2                    True                    True
# 0                       1                   False                   False
# 0                       1                    True                    True
# 0                       1                   False                     NaN
# 0                       3                    True                    True
# 0                       3                    True                    True
# 0                       1                     NaN                     NaN
# 0                       3                    True                    True
# 0                       2                   False                    True
# 0                       1                   False                   False
# 0                       1                     NaN                     NaN
# 0                       2                    True                     NaN
# 0                       2                    True                     NaN
# 0                       3                   False                     NaN
#
#    RestaurantsTakeOut  Smoking WheelchairAccessible  WiFi
# 0                 NaN      NaN                  NaN   NaN
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True    no
# 0                 NaN      NaN                  NaN   NaN
# 0                 NaN      NaN                  NaN   NaN
# 0                True      NaN                False   NaN
# 0                True      NaN                False    no
# 0                True      NaN                  NaN   NaN
# 0                 NaN      NaN                  NaN   NaN
# 0                True      NaN                 True    no
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True    no
# 0                True       no                 True    no
# 0                 NaN      NaN                 True   NaN
# 0                 NaN      NaN                  NaN   NaN
# 0               False      NaN                  NaN   NaN
# 0                True      NaN                  NaN  free
# 0                True       no                 True  free
# 0                True      NaN                False   NaN
# 0                 NaN      yes                 True   NaN
# 0                True      NaN                  NaN  free
# 0                True      NaN                 True   NaN
# 0                True      NaN                  NaN    no
# 0               False      NaN                 True   NaN
# 0                True      NaN                  NaN   NaN
# 0                True      NaN                 True    no
# 0                True      NaN                 True    no
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True  free
# 0                 NaN      NaN                  NaN   NaN
# ..                ...      ...                  ...   ...
# 0                True      NaN                  NaN   NaN
# 0               False      NaN                 True    no
# 0                True       no                 True  free
# 0                 NaN      NaN                 True   NaN
# 0               False       no                  NaN  free
# 0                True       no                 True  free
# 0                 NaN      NaN                 True   NaN
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True  free
# 0                True      yes                 True  free
# 0                True      NaN                 True    no
# 0               False      NaN                  NaN    no
# 0                 NaN      NaN                  NaN   NaN
# 0                True      NaN                 True   NaN
# 0                 NaN      yes                  NaN    no
# 0                True      NaN                  NaN  free
# 0                True      NaN                 True   NaN
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True  free
# 0                True      NaN                  NaN   NaN
# 0                True       no                 True  free
# 0               False      NaN                 True  free
# 0                True      NaN                 True  free
# 0                True       no                 True  free
# 0                True      NaN                  NaN    no
# 0                True      NaN                  NaN    no
# 0                True      NaN                 True   NaN
# 0                True      NaN                  NaN   NaN
# 0                 NaN      yes                 True  free
# 0                 NaN  outdoor                 True    no
#
# [8808 rows x 39 columns]

# %% [markdown]
# <h4>  Concatenate New Attributes Columns and older remaining columns

# %%
df_1.reset_index(drop=True, inplace=True)
df_3.reset_index(drop=True, inplace=True)
dat1 = pd.concat([df_1, df_3], axis=1)
df_1.shape,df_3.shape,dat1.shape
dat1
# Out:
#                   BusinessId                          RestaurantName  \
# 0     vJIuDBdu01vCA8y1fwR1OQ                              CakesbyToi
# 1     kgffcoxT6BQp-gJ-UQ7Czw                                  Subway
# 2     0jtRI7hVMpQHpUVtUy4ITw                  Omelet House Summerlin
# 3     JJEx5wIqs9iGGATOagE8Sg                Baja Fresh Mexican Grill
# 4     coVhQD_EAnCof_a8sGM03g                         Provence Bakery
# 5     zhxnD7J5_sCrKSw5cwI9dQ               Popeyes Louisiana Kitchen
# 6     2kWrSFkIes_d2BMg4YrRtA                               Pizza Hut
# 7     6llKs7K_tn8ChXcIM-oTvg                            Sansei Japan
# 8     nqnYDW_FMwuTejAPNEOhqA       Seasonal Adventures Pumpkin Patch
# 9     YV9GVfmDSDM7HSV0jVdTOA                           El Pollo Loco
# 10    F7OsiFk9aLZtqZczA84xpw               Popeyes Louisiana Kitchen
# 11    XeDLyY2a7nZ3IEY4RYslXA                 Chicago Brewing Company
# 12    MDVbJicJvqaO4WGx0vEabQ                                 Chili's
# 13    AAcaGYggq4RBbFdEueB2qw                    Green Valley Grocery
# 14    Zh6fxrqsKqdSVmTK3roxBQ             Triumph Property Management
# 15    sOkQ2Y1-D8h18oN5NgxuLg  Haddies Car Wash and Convenience store
# 16    OyJDaAAMr220qkZsovCARQ                               Starbucks
# 17    lv5Bnqlt93NnvNJ2oNcQ8Q                  Los Cucos Mexican Cafe
# 18    D1TaFES4phv65RmsM8VCiA                          Domino's Pizza
# 19    vTch8eXerkbaJbmkmYwCEw                      One Six Sky Lounge
# 20    glkEaoxbewiSMBiXs945JA                             800 Degrees
# 21    3TX-5V6MuGPKnZv6gW1nsg                                Cardenas
# 22    lYCeqldIiOggsbByH3RRhw                             Metro Pizza
# 23    tA1oBX1q6Aqj8UG3y-SqTA                                IT'SUGAR
# 24    juuv0QPE_MfnVjevQTpCDg                       Manhattan Streets
# 25    DbK9fyJq4O4zfT1jv6JOhw                 Pam Real Thai Las Vegas
# 26    PChG1Dm0A6AXIXkXGVK8Fw                              Sasa Sushi
# 27    owxcYAUca_6K6BAUX4V48w                           D'Pinoy Joint
# 28    WSGHEQdcdbBWXDpna99EiQ                        Teriyaki Madness
# 29    0aDCv4zPhzy7RklHDrnKQg                          Lucie's Lounge
# ...                      ...                                     ...
# 8778  diFj7LtBvNcgMy4Pb4_m0g   ROYCE' Las Vegas at Fashion Show Mall
# 8779  6xgcHeLad-VaoTIQewK84A                         N9NE Steakhouse
# 8780  _Jt9CLSL2sqF-yCNel9D-g                             Casa Robles
# 8781  5FgLuegzxBvRFw5dTuETEw                             The Chelsea
# 8782  dTsyfvRfN-zFdsgIDuQllQ                           Alder & Birch
# 8783  OaHfq01gm8PTYkJ36k1feg     Michael T's Steaks, Ribs, & Burgers
# 8784  brB2AfUTKumrRNanOZVw4w                             Scarlet Bar
# 8785  ZyTrka-HiVb6Ckcl0rDaNA               Popeyes Louisiana Kitchen
# 8786  vodCM302JJ_P9yJt1WuH_w                                Vege-Way
# 8787  YAiHkQAQ9sm23V1CyNT2zQ                     Bogey's Bar & Grill
# 8788  cYwJA2A6I12KNkm2rtXd5g                     Gordon Ramsay BurGR
# 8789  RSPEJeFTKs1BsiVgjHp1WQ                  Spago by Wolfgang Puck
# 8790  YhCh4mAs52COFPNLJUOFWQ                               Tonic Bar
# 8791  SUTTl_NCJb5JYdlMBnuVxg                       Wetzel's Pretzels
# 8792  swtA5YoSGm0V5esQuDm2NQ                                  Social
# 8793  YC1FXuG7IQneHnhbHT0XcQ                           The Lobby Bar
# 8794  WEPqQjRGviPyCKEmPhALSw                      The Coachman's Inn
# 8795  ZVetFAAt0_j0tEqiakpecA                         Jack in the Box
# 8796  WUswpeAjbiww_xkSS8jTEA          Pupusas La Familiar Restaurant
# 8797  5iAFiMPfitcYDMeII5_dnQ                           Auntie Anne's
# 8798  qtc1YZix_5lHBJTZq7DOpA                               Zeffirino
# 8799  PDIh1lVtKlUqPJROXYJQvQ                                     FIX
# 8800  TEpHybMZew9kKadvseEbEQ                             Kung Fu Tea
# 8801  g62SlImzhs6_1t-knPjd8w    Red Square Restaurant & Vodka Lounge
# 8802  UNsvHecpu_sPBeQGFxSCUA             Monthathong Thai Restaurant
# 8803  8w2Mzdz-JKy3qOpndK1Wqw                                  Subway
# 8804  qjyOjCHG9lOkZnAa8jIQ1g                           Master Donuts
# 8805  0zGeYN8ReYwVj27U7EHOJA                           American Cafe
# 8806  K9ukZjvXhDjQZnrrOPqKSw                   Montecristo Cigar Bar
# 8807  GdGXb80QKTMRP7AdPHDnuw                     Breeze Daiquiri Bar
#
#        Neighborhood                                            Address  \
# 0                                3940 Martin Luther King Blvd, Ste 101
# 1         Summerlin                                2255 N Rampart Blvd
# 2         Summerlin                                2227 N Rampart Blvd
# 3        Centennial                               7930 W Tropical Pkwy
# 4         Chinatown                            5115 Spring Mountain Rd
# 5           Sunrise                                  4505 E Bonanza Rd
# 6           Sunrise                         560 N. Nellis Blvd, Ste E1
# 7          Eastside                               3480 S Maryland Pkwy
# 8        Centennial                     6400 SE Centennial Center Blvd
# 9         Southeast                               2505 E Tropicana Ave
# 10        Southeast                               4910 S Maryland Pkwy
# 11         Westside                              2201 S Fort Apache Rd
# 12        Southeast                              7530 S Las Vegas Blvd
# 13    Spring Valley                                  6875 W Russell Rd
# 14        Summerlin                      911 North Buffalo Dr, Ste 202
# 15    Spring Valley                              9920 West Flamingo Rd
# 16                                            751 N Rancho Dr, Ste 110
# 17    Spring Valley                          7315 Arroyo Crossing Pkwy
# 18        Summerlin                        8532 Del Webb Blvd, Ste 116
# 19                                                    5255 Boulder Hwy
# 20        The Strip                              3770 Las Vegas Blvd S
# 21          Sunrise                                  4421 E Bonanza Rd
# 22        Southeast                             5757 Wayne Newton Blvd
# 23        Southeast                     6587 Las Vegas Blvd S, Ste 176
# 24        The Strip                     3717 S Las Vegas Blvd, Ste 210
# 25        Chinatown                                3650 S Decatur Blvd
# 26        Northwest                       7450 W Cheyenne Ave, Ste 118
# 27        Southeast                     7680 S Las Vegas Blvd, Ste 202
# 28                                                 7481 West Lake Mead
# 29          Sunrise                      3935 E Charleston Blvd, Ste A
# ...             ...                                                ...
# 8778      The Strip                     3200 S Las Vegas Blvd, Ste 600
# 8779                                                4321 W Flamingo Rd
# 8780                                                5900 W Flamingo Rd
# 8781      The Strip                              3708 Las Vegas Blvd S
# 8782                                              4500 W Tropicana Ave
# 8783      Southwest                             7315 W Warm Springs Rd
# 8784                                                4321 W Flamingo Rd
# 8785                                               4001 S Decatur Blvd
# 8786      Southwest                                  7790 S Jones Blvd
# 8787      Northwest                                      7770 W Ann Rd
# 8788      The Strip                              3667 Las Vegas Blvd S
# 8789      The Strip                              3600 S Las Vegas Blvd
# 8790                                             4321 West Flamingo Rd
# 8791                                             3700 Flamingo, Ste 18
# 8792                                                4321 W Flamingo Rd
# 8793      The Strip                                 75 East Harmon Ave
# 8794       Eastside                                 3240 S Eastern Ave
# 8795       Eastside                               2970 E Desert Inn Rd
# 8796       Eastside                               4524 E Tropicana Ave
# 8797      The Strip                  3200 S Las Vegas Blvd, Space 1090
# 8798      The Strip      3377 Las Vegas Blvd S, Ste 2095, The Venetian
# 8799      The Strip          Bellagio Las Vegas, 3600 S Las Vegas Blvd
# 8800      The Strip  3200 S Las Vegas Blvd, Space 7500, Fl 3rd, Sou...
# 8801      The Strip                              3950 Las Vegas Blvd S
# 8802      Southeast                                    5075 S Pecos Rd
# 8803       Eastside                               3519 S Maryland Pkwy
# 8804       Eastside                       2300 E Desert Inn Rd, Ste 11
# 8805      The Strip                              3049 Las Vegas Blvd S
# 8806      The Strip  Caesars Palace Las Vegas Hotel And Casino, 357...
# 8807      The Strip                              3475 S Las Vegas Blvd
#
#            City State    Zip  Stars  ReviewCount AcceptsInsurance  ...   \
# 0     Las Vegas    NV  89106    1.5            3              NaN  ...
# 1     Las Vegas    NV  89128    2.5           13              NaN  ...
# 2     Las Vegas    NV  89128    4.0          242              NaN  ...
# 3     Las Vegas    NV  89149    2.0            4              NaN  ...
# 4     Las Vegas    NV  89146    2.0            8              NaN  ...
# 5     Las Vegas    NV  89110    1.5           16              NaN  ...
# 6     Las Vegas    NV  89110    2.5           19              NaN  ...
# 7     Las Vegas    NV  89169    4.5            3              NaN  ...
# 8     Las Vegas    NV  89149    3.0           11              NaN  ...
# 9     Las Vegas    NV  89121    3.0           34              NaN  ...
# 10    Las Vegas    NV  89119    2.0           56              NaN  ...
# 11    Las Vegas    NV  89117    3.5          446              NaN  ...
# 12    Las Vegas    NV  89123    3.0          230              NaN  ...
# 13    Las Vegas    NV  89118    5.0            3              NaN  ...
# 14    Las Vegas    NV  89128    1.5           66              NaN  ...
# 15    Las Vegas    NV  89147    5.0            9              NaN  ...
# 16    Las Vegas    NV  89106    3.0           49              NaN  ...
# 17    Las Vegas    NV  89113    4.0          313              NaN  ...
# 18    Las Vegas    NV  89134    2.5           27              NaN  ...
# 19    Las Vegas    NV  89122    3.5           10              NaN  ...
# 20    Las Vegas    NV  89109    3.5          466              NaN  ...
# 21    Las Vegas    NV  89110    4.0           55              NaN  ...
# 22    Las Vegas    NV  89119    2.5           21              NaN  ...
# 23    Las Vegas    NV  89119    4.0           59              NaN  ...
# 24    Las Vegas    NV  89109    3.5            7              NaN  ...
# 25    Las Vegas    NV  89103    4.0           77              NaN  ...
# 26    Las Vegas    NV  89129    4.0          509              NaN  ...
# 27    Las Vegas    NV  89123    4.5          134              NaN  ...
# 28    Las Vegas    NV  89128    3.5          119              NaN  ...
# 29    Las Vegas    NV  89104    4.0           10              NaN  ...
# ...         ...   ...    ...    ...          ...              ...  ...
# 8778  Las Vegas    NV  89109    5.0            4              NaN  ...
# 8779  Las Vegas    NV  89103    4.0          834              NaN  ...
# 8780  Las Vegas    NV  89103    5.0           24              NaN  ...
# 8781  Las Vegas    NV  89109    4.0           97              NaN  ...
# 8782  Las Vegas    NV  89103    4.5          133              NaN  ...
# 8783  Las Vegas    NV  89113    4.0           97              NaN  ...
# 8784  Las Vegas    NV  89103    4.0           16              NaN  ...
# 8785  Las Vegas    NV  89103    3.5           15              NaN  ...
# 8786  Las Vegas    NV  89139    4.0          415              NaN  ...
# 8787  Las Vegas    NV  89149    3.0           19              NaN  ...
# 8788  Las Vegas    NV  89109    4.0         5472              NaN  ...
# 8789  Las Vegas    NV  89109    4.0           17              NaN  ...
# 8790  Las Vegas    NV  89103    3.5            3              NaN  ...
# 8791  Las Vegas    NV  89103    3.5           15              NaN  ...
# 8792  Las Vegas    NV  89103    4.0           19              NaN  ...
# 8793  Las Vegas    NV  89109    4.0            6              NaN  ...
# 8794  Las Vegas    NV  89169    4.0           20              NaN  ...
# 8795  Las Vegas    NV  89121    2.5           15              NaN  ...
# 8796  Las Vegas    NV  89121    3.0           41              NaN  ...
# 8797  Las Vegas    NV  89109    3.0           22              NaN  ...
# 8798  Las Vegas    NV  89109    3.5          402              NaN  ...
# 8799  Las Vegas    NV  89109    3.5          636              NaN  ...
# 8800  Las Vegas    NV  89109    4.0           66              NaN  ...
# 8801  Las Vegas    NV  89119    4.0          619              NaN  ...
# 8802  Las Vegas    NV  89120    4.5            5              NaN  ...
# 8803  Las Vegas    NV  89169    2.0           12              NaN  ...
# 8804  Las Vegas    NV  89169    4.5           86              NaN  ...
# 8805  Las Vegas    NV  89109    2.5            7              NaN  ...
# 8806  Las Vegas    NV  89109    4.5          108              NaN  ...
# 8807  Las Vegas    NV  89109    4.0            5              NaN  ...
#
#      RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 0                          NaN               False                      NaN
# 1                          NaN               False                     True
# 2                          NaN               False                     True
# 3                          NaN                 NaN                      NaN
# 4                          NaN                 NaN                      NaN
# 5                          NaN               False                     True
# 6                          NaN                True                     True
# 7                          NaN               False                     True
# 8                          NaN                 NaN                      NaN
# 9                          NaN               False                     True
# 10                         NaN               False                     True
# 11                         NaN               False                     True
# 12                         NaN               False                     True
# 13                         NaN                 NaN                      NaN
# 14                         NaN                 NaN                      NaN
# 15                         NaN               False                      NaN
# 16                         NaN               False                      NaN
# 17                         NaN               False                     True
# 18                         NaN                True                     True
# 19                         NaN                 NaN                     True
# 20                         NaN               False                     True
# 21                         NaN                 NaN                      NaN
# 22                         NaN               False                     True
# 23                         NaN                 NaN                      NaN
# 24                         NaN               False                     True
# 25                         NaN                True                     True
# 26                         NaN               False                     True
# 27                         NaN               False                     True
# 28                         NaN               False                     True
# 29                         NaN                 NaN                     True
# ...                        ...                 ...                      ...
# 8778                       NaN                 NaN                      NaN
# 8779                       NaN               False                     True
# 8780                       NaN               False                     True
# 8781                       NaN                 NaN                      NaN
# 8782                       NaN               False                     True
# 8783                       NaN               False                     True
# 8784                       NaN                 NaN                    False
# 8785                       NaN               False                     True
# 8786                       NaN               False                     True
# 8787                       NaN               False                     True
# 8788                       NaN               False                     True
# 8789                       NaN               False                     True
# 8790                       NaN                 NaN                     True
# 8791                       NaN                 NaN                      NaN
# 8792                       NaN                 NaN                     True
# 8793                       NaN               False                     True
# 8794                       NaN                 NaN                     True
# 8795                       NaN               False                     True
# 8796                       NaN                True                     True
# 8797                       NaN               False                     True
# 8798                       NaN               False                     True
# 8799                       NaN               False                     True
# 8800                       NaN                 NaN                      NaN
# 8801                      True               False                     True
# 8802                       NaN                True                     True
# 8803                       NaN               False                     True
# 8804                       NaN                 NaN                      NaN
# 8805                       NaN                True                     True
# 8806                       NaN                 NaN                     True
# 8807                       NaN                 NaN                    False
#
#      RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 0                       NaN                     NaN                     NaN
# 1                         1                   False                   False
# 2                         2                   False                    True
# 3                       NaN                   False                     NaN
# 4                         1                     NaN                     NaN
# 5                         1                   False                   False
# 6                         2                   False                   False
# 7                         1                   False                     NaN
# 8                       NaN                     NaN                     NaN
# 9                         1                   False                   False
# 10                        1                   False                   False
# 11                        2                    True                    True
# 12                        2                    True                    True
# 13                        2                     NaN                     NaN
# 14                      NaN                     NaN                     NaN
# 15                        2                   False                     NaN
# 16                        1                     NaN                     NaN
# 17                        2                    True                    True
# 18                        2                   False                     NaN
# 19                        1                     NaN                     NaN
# 20                        2                   False                   False
# 21                        1                     NaN                     NaN
# 22                        1                   False                   False
# 23                        2                     NaN                     NaN
# 24                        1                     NaN                   False
# 25                        1                    True                    True
# 26                        2                    True                    True
# 27                        2                    True                    True
# 28                        1                   False                   False
# 29                        1                     NaN                     NaN
# ...                     ...                     ...                     ...
# 8778                      2                     NaN                     NaN
# 8779                      4                    True                    True
# 8780                      2                    True                    True
# 8781                    NaN                     NaN                     NaN
# 8782                      3                    True                    True
# 8783                      2                    True                    True
# 8784                      3                     NaN                     NaN
# 8785                      1                   False                   False
# 8786                      1                   False                   False
# 8787                      2                    True                    True
# 8788                      2                   False                    True
# 8789                      2                    True                     NaN
# 8790                      2                   False                     NaN
# 8791                      1                     NaN                     NaN
# 8792                      2                   False                     NaN
# 8793                      2                   False                     NaN
# 8794                      2                    True                    True
# 8795                      1                   False                   False
# 8796                      1                    True                    True
# 8797                      1                   False                     NaN
# 8798                      3                    True                    True
# 8799                      3                    True                    True
# 8800                      1                     NaN                     NaN
# 8801                      3                    True                    True
# 8802                      2                   False                    True
# 8803                      1                   False                   False
# 8804                      1                     NaN                     NaN
# 8805                      2                    True                     NaN
# 8806                      2                    True                     NaN
# 8807                      3                   False                     NaN
#
#      RestaurantsTakeOut  Smoking WheelchairAccessible  WiFi
# 0                   NaN      NaN                  NaN   NaN
# 1                  True      NaN                  NaN    no
# 2                  True      NaN                 True    no
# 3                   NaN      NaN                  NaN   NaN
# 4                   NaN      NaN                  NaN   NaN
# 5                  True      NaN                False   NaN
# 6                  True      NaN                False    no
# 7                  True      NaN                  NaN   NaN
# 8                   NaN      NaN                  NaN   NaN
# 9                  True      NaN                 True    no
# 10                 True      NaN                  NaN    no
# 11                 True      NaN                 True    no
# 12                 True       no                 True    no
# 13                  NaN      NaN                 True   NaN
# 14                  NaN      NaN                  NaN   NaN
# 15                False      NaN                  NaN   NaN
# 16                 True      NaN                  NaN  free
# 17                 True       no                 True  free
# 18                 True      NaN                False   NaN
# 19                  NaN      yes                 True   NaN
# 20                 True      NaN                  NaN  free
# 21                 True      NaN                 True   NaN
# 22                 True      NaN                  NaN    no
# 23                False      NaN                 True   NaN
# 24                 True      NaN                  NaN   NaN
# 25                 True      NaN                 True    no
# 26                 True      NaN                 True    no
# 27                 True      NaN                  NaN    no
# 28                 True      NaN                 True  free
# 29                  NaN      NaN                  NaN   NaN
# ...                 ...      ...                  ...   ...
# 8778               True      NaN                  NaN   NaN
# 8779              False      NaN                 True    no
# 8780               True       no                 True  free
# 8781                NaN      NaN                 True   NaN
# 8782              False       no                  NaN  free
# 8783               True       no                 True  free
# 8784                NaN      NaN                 True   NaN
# 8785               True      NaN                  NaN    no
# 8786               True      NaN                 True  free
# 8787               True      yes                 True  free
# 8788               True      NaN                 True    no
# 8789              False      NaN                  NaN    no
# 8790                NaN      NaN                  NaN   NaN
# 8791               True      NaN                 True   NaN
# 8792                NaN      yes                  NaN    no
# 8793               True      NaN                  NaN  free
# 8794               True      NaN                 True   NaN
# 8795               True      NaN                  NaN    no
# 8796               True      NaN                 True  free
# 8797               True      NaN                  NaN   NaN
# 8798               True       no                 True  free
# 8799              False      NaN                 True  free
# 8800               True      NaN                 True  free
# 8801               True       no                 True  free
# 8802               True      NaN                  NaN    no
# 8803               True      NaN                  NaN    no
# 8804               True      NaN                 True   NaN
# 8805               True      NaN                  NaN   NaN
# 8806                NaN      yes                 True  free
# 8807                NaN  outdoor                 True    no
#
# [8808 rows x 48 columns]

# %% [markdown]
# <h3> Mapping Values

# %% [markdown]
# <h4> All True=1, False=0

# %%
dat1.replace('True',1,inplace=True)
dat1.replace('False',0,inplace=True)
dat1
# Out:
#                   BusinessId                          RestaurantName  \
# 0     vJIuDBdu01vCA8y1fwR1OQ                              CakesbyToi
# 1     kgffcoxT6BQp-gJ-UQ7Czw                                  Subway
# 2     0jtRI7hVMpQHpUVtUy4ITw                  Omelet House Summerlin
# 3     JJEx5wIqs9iGGATOagE8Sg                Baja Fresh Mexican Grill
# 4     coVhQD_EAnCof_a8sGM03g                         Provence Bakery
# 5     zhxnD7J5_sCrKSw5cwI9dQ               Popeyes Louisiana Kitchen
# 6     2kWrSFkIes_d2BMg4YrRtA                               Pizza Hut
# 7     6llKs7K_tn8ChXcIM-oTvg                            Sansei Japan
# 8     nqnYDW_FMwuTejAPNEOhqA       Seasonal Adventures Pumpkin Patch
# 9     YV9GVfmDSDM7HSV0jVdTOA                           El Pollo Loco
# 10    F7OsiFk9aLZtqZczA84xpw               Popeyes Louisiana Kitchen
# 11    XeDLyY2a7nZ3IEY4RYslXA                 Chicago Brewing Company
# 12    MDVbJicJvqaO4WGx0vEabQ                                 Chili's
# 13    AAcaGYggq4RBbFdEueB2qw                    Green Valley Grocery
# 14    Zh6fxrqsKqdSVmTK3roxBQ             Triumph Property Management
# 15    sOkQ2Y1-D8h18oN5NgxuLg  Haddies Car Wash and Convenience store
# 16    OyJDaAAMr220qkZsovCARQ                               Starbucks
# 17    lv5Bnqlt93NnvNJ2oNcQ8Q                  Los Cucos Mexican Cafe
# 18    D1TaFES4phv65RmsM8VCiA                          Domino's Pizza
# 19    vTch8eXerkbaJbmkmYwCEw                      One Six Sky Lounge
# 20    glkEaoxbewiSMBiXs945JA                             800 Degrees
# 21    3TX-5V6MuGPKnZv6gW1nsg                                Cardenas
# 22    lYCeqldIiOggsbByH3RRhw                             Metro Pizza
# 23    tA1oBX1q6Aqj8UG3y-SqTA                                IT'SUGAR
# 24    juuv0QPE_MfnVjevQTpCDg                       Manhattan Streets
# 25    DbK9fyJq4O4zfT1jv6JOhw                 Pam Real Thai Las Vegas
# 26    PChG1Dm0A6AXIXkXGVK8Fw                              Sasa Sushi
# 27    owxcYAUca_6K6BAUX4V48w                           D'Pinoy Joint
# 28    WSGHEQdcdbBWXDpna99EiQ                        Teriyaki Madness
# 29    0aDCv4zPhzy7RklHDrnKQg                          Lucie's Lounge
# ...                      ...                                     ...
# 8778  diFj7LtBvNcgMy4Pb4_m0g   ROYCE' Las Vegas at Fashion Show Mall
# 8779  6xgcHeLad-VaoTIQewK84A                         N9NE Steakhouse
# 8780  _Jt9CLSL2sqF-yCNel9D-g                             Casa Robles
# 8781  5FgLuegzxBvRFw5dTuETEw                             The Chelsea
# 8782  dTsyfvRfN-zFdsgIDuQllQ                           Alder & Birch
# 8783  OaHfq01gm8PTYkJ36k1feg     Michael T's Steaks, Ribs, & Burgers
# 8784  brB2AfUTKumrRNanOZVw4w                             Scarlet Bar
# 8785  ZyTrka-HiVb6Ckcl0rDaNA               Popeyes Louisiana Kitchen
# 8786  vodCM302JJ_P9yJt1WuH_w                                Vege-Way
# 8787  YAiHkQAQ9sm23V1CyNT2zQ                     Bogey's Bar & Grill
# 8788  cYwJA2A6I12KNkm2rtXd5g                     Gordon Ramsay BurGR
# 8789  RSPEJeFTKs1BsiVgjHp1WQ                  Spago by Wolfgang Puck
# 8790  YhCh4mAs52COFPNLJUOFWQ                               Tonic Bar
# 8791  SUTTl_NCJb5JYdlMBnuVxg                       Wetzel's Pretzels
# 8792  swtA5YoSGm0V5esQuDm2NQ                                  Social
# 8793  YC1FXuG7IQneHnhbHT0XcQ                           The Lobby Bar
# 8794  WEPqQjRGviPyCKEmPhALSw                      The Coachman's Inn
# 8795  ZVetFAAt0_j0tEqiakpecA                         Jack in the Box
# 8796  WUswpeAjbiww_xkSS8jTEA          Pupusas La Familiar Restaurant
# 8797  5iAFiMPfitcYDMeII5_dnQ                           Auntie Anne's
# 8798  qtc1YZix_5lHBJTZq7DOpA                               Zeffirino
# 8799  PDIh1lVtKlUqPJROXYJQvQ                                     FIX
# 8800  TEpHybMZew9kKadvseEbEQ                             Kung Fu Tea
# 8801  g62SlImzhs6_1t-knPjd8w    Red Square Restaurant & Vodka Lounge
# 8802  UNsvHecpu_sPBeQGFxSCUA             Monthathong Thai Restaurant
# 8803  8w2Mzdz-JKy3qOpndK1Wqw                                  Subway
# 8804  qjyOjCHG9lOkZnAa8jIQ1g                           Master Donuts
# 8805  0zGeYN8ReYwVj27U7EHOJA                           American Cafe
# 8806  K9ukZjvXhDjQZnrrOPqKSw                   Montecristo Cigar Bar
# 8807  GdGXb80QKTMRP7AdPHDnuw                     Breeze Daiquiri Bar
#
#        Neighborhood                                            Address  \
# 0                                3940 Martin Luther King Blvd, Ste 101
# 1         Summerlin                                2255 N Rampart Blvd
# 2         Summerlin                                2227 N Rampart Blvd
# 3        Centennial                               7930 W Tropical Pkwy
# 4         Chinatown                            5115 Spring Mountain Rd
# 5           Sunrise                                  4505 E Bonanza Rd
# 6           Sunrise                         560 N. Nellis Blvd, Ste E1
# 7          Eastside                               3480 S Maryland Pkwy
# 8        Centennial                     6400 SE Centennial Center Blvd
# 9         Southeast                               2505 E Tropicana Ave
# 10        Southeast                               4910 S Maryland Pkwy
# 11         Westside                              2201 S Fort Apache Rd
# 12        Southeast                              7530 S Las Vegas Blvd
# 13    Spring Valley                                  6875 W Russell Rd
# 14        Summerlin                      911 North Buffalo Dr, Ste 202
# 15    Spring Valley                              9920 West Flamingo Rd
# 16                                            751 N Rancho Dr, Ste 110
# 17    Spring Valley                          7315 Arroyo Crossing Pkwy
# 18        Summerlin                        8532 Del Webb Blvd, Ste 116
# 19                                                    5255 Boulder Hwy
# 20        The Strip                              3770 Las Vegas Blvd S
# 21          Sunrise                                  4421 E Bonanza Rd
# 22        Southeast                             5757 Wayne Newton Blvd
# 23        Southeast                     6587 Las Vegas Blvd S, Ste 176
# 24        The Strip                     3717 S Las Vegas Blvd, Ste 210
# 25        Chinatown                                3650 S Decatur Blvd
# 26        Northwest                       7450 W Cheyenne Ave, Ste 118
# 27        Southeast                     7680 S Las Vegas Blvd, Ste 202
# 28                                                 7481 West Lake Mead
# 29          Sunrise                      3935 E Charleston Blvd, Ste A
# ...             ...                                                ...
# 8778      The Strip                     3200 S Las Vegas Blvd, Ste 600
# 8779                                                4321 W Flamingo Rd
# 8780                                                5900 W Flamingo Rd
# 8781      The Strip                              3708 Las Vegas Blvd S
# 8782                                              4500 W Tropicana Ave
# 8783      Southwest                             7315 W Warm Springs Rd
# 8784                                                4321 W Flamingo Rd
# 8785                                               4001 S Decatur Blvd
# 8786      Southwest                                  7790 S Jones Blvd
# 8787      Northwest                                      7770 W Ann Rd
# 8788      The Strip                              3667 Las Vegas Blvd S
# 8789      The Strip                              3600 S Las Vegas Blvd
# 8790                                             4321 West Flamingo Rd
# 8791                                             3700 Flamingo, Ste 18
# 8792                                                4321 W Flamingo Rd
# 8793      The Strip                                 75 East Harmon Ave
# 8794       Eastside                                 3240 S Eastern Ave
# 8795       Eastside                               2970 E Desert Inn Rd
# 8796       Eastside                               4524 E Tropicana Ave
# 8797      The Strip                  3200 S Las Vegas Blvd, Space 1090
# 8798      The Strip      3377 Las Vegas Blvd S, Ste 2095, The Venetian
# 8799      The Strip          Bellagio Las Vegas, 3600 S Las Vegas Blvd
# 8800      The Strip  3200 S Las Vegas Blvd, Space 7500, Fl 3rd, Sou...
# 8801      The Strip                              3950 Las Vegas Blvd S
# 8802      Southeast                                    5075 S Pecos Rd
# 8803       Eastside                               3519 S Maryland Pkwy
# 8804       Eastside                       2300 E Desert Inn Rd, Ste 11
# 8805      The Strip                              3049 Las Vegas Blvd S
# 8806      The Strip  Caesars Palace Las Vegas Hotel And Casino, 357...
# 8807      The Strip                              3475 S Las Vegas Blvd
#
#            City State    Zip  Stars  ReviewCount  AcceptsInsurance  ...   \
# 0     Las Vegas    NV  89106    1.5            3               NaN  ...
# 1     Las Vegas    NV  89128    2.5           13               NaN  ...
# 2     Las Vegas    NV  89128    4.0          242               NaN  ...
# 3     Las Vegas    NV  89149    2.0            4               NaN  ...
# 4     Las Vegas    NV  89146    2.0            8               NaN  ...
# 5     Las Vegas    NV  89110    1.5           16               NaN  ...
# 6     Las Vegas    NV  89110    2.5           19               NaN  ...
# 7     Las Vegas    NV  89169    4.5            3               NaN  ...
# 8     Las Vegas    NV  89149    3.0           11               NaN  ...
# 9     Las Vegas    NV  89121    3.0           34               NaN  ...
# 10    Las Vegas    NV  89119    2.0           56               NaN  ...
# 11    Las Vegas    NV  89117    3.5          446               NaN  ...
# 12    Las Vegas    NV  89123    3.0          230               NaN  ...
# 13    Las Vegas    NV  89118    5.0            3               NaN  ...
# 14    Las Vegas    NV  89128    1.5           66               NaN  ...
# 15    Las Vegas    NV  89147    5.0            9               NaN  ...
# 16    Las Vegas    NV  89106    3.0           49               NaN  ...
# 17    Las Vegas    NV  89113    4.0          313               NaN  ...
# 18    Las Vegas    NV  89134    2.5           27               NaN  ...
# 19    Las Vegas    NV  89122    3.5           10               NaN  ...
# 20    Las Vegas    NV  89109    3.5          466               NaN  ...
# 21    Las Vegas    NV  89110    4.0           55               NaN  ...
# 22    Las Vegas    NV  89119    2.5           21               NaN  ...
# 23    Las Vegas    NV  89119    4.0           59               NaN  ...
# 24    Las Vegas    NV  89109    3.5            7               NaN  ...
# 25    Las Vegas    NV  89103    4.0           77               NaN  ...
# 26    Las Vegas    NV  89129    4.0          509               NaN  ...
# 27    Las Vegas    NV  89123    4.5          134               NaN  ...
# 28    Las Vegas    NV  89128    3.5          119               NaN  ...
# 29    Las Vegas    NV  89104    4.0           10               NaN  ...
# ...         ...   ...    ...    ...          ...               ...  ...
# 8778  Las Vegas    NV  89109    5.0            4               NaN  ...
# 8779  Las Vegas    NV  89103    4.0          834               NaN  ...
# 8780  Las Vegas    NV  89103    5.0           24               NaN  ...
# 8781  Las Vegas    NV  89109    4.0           97               NaN  ...
# 8782  Las Vegas    NV  89103    4.5          133               NaN  ...
# 8783  Las Vegas    NV  89113    4.0           97               NaN  ...
# 8784  Las Vegas    NV  89103    4.0           16               NaN  ...
# 8785  Las Vegas    NV  89103    3.5           15               NaN  ...
# 8786  Las Vegas    NV  89139    4.0          415               NaN  ...
# 8787  Las Vegas    NV  89149    3.0           19               NaN  ...
# 8788  Las Vegas    NV  89109    4.0         5472               NaN  ...
# 8789  Las Vegas    NV  89109    4.0           17               NaN  ...
# 8790  Las Vegas    NV  89103    3.5            3               NaN  ...
# 8791  Las Vegas    NV  89103    3.5           15               NaN  ...
# 8792  Las Vegas    NV  89103    4.0           19               NaN  ...
# 8793  Las Vegas    NV  89109    4.0            6               NaN  ...
# 8794  Las Vegas    NV  89169    4.0           20               NaN  ...
# 8795  Las Vegas    NV  89121    2.5           15               NaN  ...
# 8796  Las Vegas    NV  89121    3.0           41               NaN  ...
# 8797  Las Vegas    NV  89109    3.0           22               NaN  ...
# 8798  Las Vegas    NV  89109    3.5          402               NaN  ...
# 8799  Las Vegas    NV  89109    3.5          636               NaN  ...
# 8800  Las Vegas    NV  89109    4.0           66               NaN  ...
# 8801  Las Vegas    NV  89119    4.0          619               NaN  ...
# 8802  Las Vegas    NV  89120    4.5            5               NaN  ...
# 8803  Las Vegas    NV  89169    2.0           12               NaN  ...
# 8804  Las Vegas    NV  89169    4.5           86               NaN  ...
# 8805  Las Vegas    NV  89109    2.5            7               NaN  ...
# 8806  Las Vegas    NV  89109    4.5          108               NaN  ...
# 8807  Las Vegas    NV  89109    4.0            5               NaN  ...
#
#      RestaurantsCounterService RestaurantsDelivery RestaurantsGoodForGroups  \
# 0                          NaN                 0.0                      NaN
# 1                          NaN                 0.0                      1.0
# 2                          NaN                 0.0                      1.0
# 3                          NaN                 NaN                      NaN
# 4                          NaN                 NaN                      NaN
# 5                          NaN                 0.0                      1.0
# 6                          NaN                 1.0                      1.0
# 7                          NaN                 0.0                      1.0
# 8                          NaN                 NaN                      NaN
# 9                          NaN                 0.0                      1.0
# 10                         NaN                 0.0                      1.0
# 11                         NaN                 0.0                      1.0
# 12                         NaN                 0.0                      1.0
# 13                         NaN                 NaN                      NaN
# 14                         NaN                 NaN                      NaN
# 15                         NaN                 0.0                      NaN
# 16                         NaN                 0.0                      NaN
# 17                         NaN                 0.0                      1.0
# 18                         NaN                 1.0                      1.0
# 19                         NaN                 NaN                      1.0
# 20                         NaN                 0.0                      1.0
# 21                         NaN                 NaN                      NaN
# 22                         NaN                 0.0                      1.0
# 23                         NaN                 NaN                      NaN
# 24                         NaN                 0.0                      1.0
# 25                         NaN                 1.0                      1.0
# 26                         NaN                 0.0                      1.0
# 27                         NaN                 0.0                      1.0
# 28                         NaN                 0.0                      1.0
# 29                         NaN                 NaN                      1.0
# ...                        ...                 ...                      ...
# 8778                       NaN                 NaN                      NaN
# 8779                       NaN                 0.0                      1.0
# 8780                       NaN                 0.0                      1.0
# 8781                       NaN                 NaN                      NaN
# 8782                       NaN                 0.0                      1.0
# 8783                       NaN                 0.0                      1.0
# 8784                       NaN                 NaN                      0.0
# 8785                       NaN                 0.0                      1.0
# 8786                       NaN                 0.0                      1.0
# 8787                       NaN                 0.0                      1.0
# 8788                       NaN                 0.0                      1.0
# 8789                       NaN                 0.0                      1.0
# 8790                       NaN                 NaN                      1.0
# 8791                       NaN                 NaN                      NaN
# 8792                       NaN                 NaN                      1.0
# 8793                       NaN                 0.0                      1.0
# 8794                       NaN                 NaN                      1.0
# 8795                       NaN                 0.0                      1.0
# 8796                       NaN                 1.0                      1.0
# 8797                       NaN                 0.0                      1.0
# 8798                       NaN                 0.0                      1.0
# 8799                       NaN                 0.0                      1.0
# 8800                       NaN                 NaN                      NaN
# 8801                       1.0                 0.0                      1.0
# 8802                       NaN                 1.0                      1.0
# 8803                       NaN                 0.0                      1.0
# 8804                       NaN                 NaN                      NaN
# 8805                       NaN                 1.0                      1.0
# 8806                       NaN                 NaN                      1.0
# 8807                       NaN                 NaN                      0.0
#
#       RestaurantsPriceRange2 RestaurantsReservations RestaurantsTableService  \
# 0                        NaN                     NaN                     NaN
# 1                          1                     0.0                     0.0
# 2                          2                     0.0                     1.0
# 3                        NaN                     0.0                     NaN
# 4                          1                     NaN                     NaN
# 5                          1                     0.0                     0.0
# 6                          2                     0.0                     0.0
# 7                          1                     0.0                     NaN
# 8                        NaN                     NaN                     NaN
# 9                          1                     0.0                     0.0
# 10                         1                     0.0                     0.0
# 11                         2                     1.0                     1.0
# 12                         2                     1.0                     1.0
# 13                         2                     NaN                     NaN
# 14                       NaN                     NaN                     NaN
# 15                         2                     0.0                     NaN
# 16                         1                     NaN                     NaN
# 17                         2                     1.0                     1.0
# 18                         2                     0.0                     NaN
# 19                         1                     NaN                     NaN
# 20                         2                     0.0                     0.0
# 21                         1                     NaN                     NaN
# 22                         1                     0.0                     0.0
# 23                         2                     NaN                     NaN
# 24                         1                     NaN                     0.0
# 25                         1                     1.0                     1.0
# 26                         2                     1.0                     1.0
# 27                         2                     1.0                     1.0
# 28                         1                     0.0                     0.0
# 29                         1                     NaN                     NaN
# ...                      ...                     ...                     ...
# 8778                       2                     NaN                     NaN
# 8779                       4                     1.0                     1.0
# 8780                       2                     1.0                     1.0
# 8781                     NaN                     NaN                     NaN
# 8782                       3                     1.0                     1.0
# 8783                       2                     1.0                     1.0
# 8784                       3                     NaN                     NaN
# 8785                       1                     0.0                     0.0
# 8786                       1                     0.0                     0.0
# 8787                       2                     1.0                     1.0
# 8788                       2                     0.0                     1.0
# 8789                       2                     1.0                     NaN
# 8790                       2                     0.0                     NaN
# 8791                       1                     NaN                     NaN
# 8792                       2                     0.0                     NaN
# 8793                       2                     0.0                     NaN
# 8794                       2                     1.0                     1.0
# 8795                       1                     0.0                     0.0
# 8796                       1                     1.0                     1.0
# 8797                       1                     0.0                     NaN
# 8798                       3                     1.0                     1.0
# 8799                       3                     1.0                     1.0
# 8800                       1                     NaN                     NaN
# 8801                       3                     1.0                     1.0
# 8802                       2                     0.0                     1.0
# 8803                       1                     0.0                     0.0
# 8804                       1                     NaN                     NaN
# 8805                       2                     1.0                     NaN
# 8806                       2                     1.0                     NaN
# 8807                       3                     0.0                     NaN
#
#       RestaurantsTakeOut  Smoking  WheelchairAccessible  WiFi
# 0                    NaN      NaN                   NaN   NaN
# 1                    1.0      NaN                   NaN    no
# 2                    1.0      NaN                   1.0    no
# 3                    NaN      NaN                   NaN   NaN
# 4                    NaN      NaN                   NaN   NaN
# 5                    1.0      NaN                   0.0   NaN
# 6                    1.0      NaN                   0.0    no
# 7                    1.0      NaN                   NaN   NaN
# 8                    NaN      NaN                   NaN   NaN
# 9                    1.0      NaN                   1.0    no
# 10                   1.0      NaN                   NaN    no
# 11                   1.0      NaN                   1.0    no
# 12                   1.0       no                   1.0    no
# 13                   NaN      NaN                   1.0   NaN
# 14                   NaN      NaN                   NaN   NaN
# 15                   0.0      NaN                   NaN   NaN
# 16                   1.0      NaN                   NaN  free
# 17                   1.0       no                   1.0  free
# 18                   1.0      NaN                   0.0   NaN
# 19                   NaN      yes                   1.0   NaN
# 20                   1.0      NaN                   NaN  free
# 21                   1.0      NaN                   1.0   NaN
# 22                   1.0      NaN                   NaN    no
# 23                   0.0      NaN                   1.0   NaN
# 24                   1.0      NaN                   NaN   NaN
# 25                   1.0      NaN                   1.0    no
# 26                   1.0      NaN                   1.0    no
# 27                   1.0      NaN                   NaN    no
# 28                   1.0      NaN                   1.0  free
# 29                   NaN      NaN                   NaN   NaN
# ...                  ...      ...                   ...   ...
# 8778                 1.0      NaN                   NaN   NaN
# 8779                 0.0      NaN                   1.0    no
# 8780                 1.0       no                   1.0  free
# 8781                 NaN      NaN                   1.0   NaN
# 8782                 0.0       no                   NaN  free
# 8783                 1.0       no                   1.0  free
# 8784                 NaN      NaN                   1.0   NaN
# 8785                 1.0      NaN                   NaN    no
# 8786                 1.0      NaN                   1.0  free
# 8787                 1.0      yes                   1.0  free
# 8788                 1.0      NaN                   1.0    no
# 8789                 0.0      NaN                   NaN    no
# 8790                 NaN      NaN                   NaN   NaN
# 8791                 1.0      NaN                   1.0   NaN
# 8792                 NaN      yes                   NaN    no
# 8793                 1.0      NaN                   NaN  free
# 8794                 1.0      NaN                   1.0   NaN
# 8795                 1.0      NaN                   NaN    no
# 8796                 1.0      NaN                   1.0  free
# 8797                 1.0      NaN                   NaN   NaN
# 8798                 1.0       no                   1.0  free
# 8799                 0.0      NaN                   1.0  free
# 8800                 1.0      NaN                   1.0  free
# 8801                 1.0       no                   1.0  free
# 8802                 1.0      NaN                   NaN    no
# 8803                 1.0      NaN                   NaN    no
# 8804                 1.0      NaN                   1.0   NaN
# 8805                 1.0      NaN                   NaN   NaN
# 8806                 NaN      yes                   1.0  free
# 8807                 NaN  outdoor                   1.0    no
#
# [8808 rows x 48 columns]

# %%
dat1.columns.values
# Out:
# array(['BusinessId', 'RestaurantName', 'Neighborhood', 'Address', 'City',
#        'State', 'Zip', 'Stars', 'ReviewCount', 'AcceptsInsurance',
#        'AgesAllowed', 'Alcohol', 'Ambience', 'BYOB', 'BYOBCorkage',
#        'BestNights', 'BikeParking', 'BusinessAcceptsBitcoin',
#        'BusinessAcceptsCreditCards', 'BusinessParking',
#        'ByAppointmentOnly', 'Caters', 'CoatCheck', 'Corkage',
#        'DietaryRestrictions', 'DogsAllowed', 'DriveThru', 'GoodForDancing',
#        'GoodForKids', 'GoodForMeal', 'HairSpecializesIn', 'HappyHour',
#        'HasTV', 'Music', 'NoiseLevel', 'Open24Hours', 'OutdoorSeating',
#        'RestaurantsAttire', 'RestaurantsCounterService',
#        'RestaurantsDelivery', 'RestaurantsGoodForGroups',
#        'RestaurantsPriceRange2', 'RestaurantsReservations',
#        'RestaurantsTableService', 'RestaurantsTakeOut', 'Smoking',
#        'WheelchairAccessible', 'WiFi'], dtype=object)

# %%
dat1.HasTV.unique()
dat1.WheelchairAccessible.unique()
dat1.HappyHour.unique()
dat1.GoodForDancing.unique()
dat1.DriveThru.unique()
dat1.DogsAllowed.unique()
dat1.Corkage.unique()
dat1.RestaurantsReservations.unique()
dat1.RestaurantsTableService.unique()
dat1.RestaurantsTakeOut.unique()
dat1.RestaurantsCounterService.unique()
dat1.RestaurantsDelivery.unique()
dat1.RestaurantsGoodForGroups.unique()
dat1.CoatCheck.unique()
dat1.Caters.unique()
dat1.ByAppointmentOnly.unique()
dat1.BusinessAcceptsCreditCards.unique()
dat1.BusinessAcceptsBitcoin.unique()
dat1.BikeParking.unique()
dat1.BYOB.unique()
dat1.GoodForKids.unique()
dat1.Open24Hours.unique()
dat1.OutdoorSeating.unique()
dat1.AcceptsInsurance.unique()
# Out:
# array([ nan,   0.,   1.])

# %%
dat1.WiFi.unique()
#Mapping : no=0,free=1, paid=2
dat1.WiFi.replace('no',0,inplace=True)
dat1.WiFi.replace('free',1,inplace=True)
dat1.WiFi.replace('paid',2,inplace=True)
dat1.WiFi.unique()
# Out:
# array([ nan,   0.,   1.,   2.])

# %%
dat1.Smoking.unique()
#Mapping : no=0, yes=1, outdoor=2
dat1.Smoking.replace('no',0,inplace=True)
dat1.Smoking.replace('yes',1,inplace=True)
dat1.Smoking.replace('outdoor',2,inplace=True)
dat1.Smoking.unique()
# Out:
# array([ nan,   0.,   1.,   2.])

# %%
#Dont Know what they represent
dat1.RestaurantsPriceRange2.unique()
# Out:
# array([nan, '1', '2', '3', '4'], dtype=object)

# %%
dat1.RestaurantsAttire.unique()
#Mapping : casual=0, dressy=1, formal=2
dat1.RestaurantsAttire.replace('casual',0,inplace=True)
dat1.RestaurantsAttire.replace('dressy',1,inplace=True)
dat1.RestaurantsAttire.replace('formal',2,inplace=True)
dat1.RestaurantsAttire.unique()
# Out:
# array([ nan,   0.,   1.,   2.])

# %%
dat1.NoiseLevel.unique()
#Mapping : quiet=0,average=1, loud=2, very_loud=3
dat1.NoiseLevel.replace('quiet',0,inplace=True)
dat1.NoiseLevel.replace('average',1,inplace=True)
dat1.NoiseLevel.replace('loud',2,inplace=True)
dat1.NoiseLevel.replace('very_loud',3,inplace=True)
dat1.NoiseLevel.unique()
# Out:
# array([ nan,   1.,   2.,   0.,   3.])

# %%
dat1.BYOBCorkage.unique()
#Mapping : no->0, yes_free->1, yes_corkage->2
dat1.BYOBCorkage.replace('no',0,inplace=True)
dat1.BYOBCorkage.replace('yes_free',1,inplace=True)
dat1.BYOBCorkage.replace('yes_corkage',2,inplace=True)
dat1.BYOBCorkage.unique()
# Out:
# array([ nan,   1.,   0.,   2.])

# %%
#Range of Ages Allowed
dat1.AgesAllowed.unique()
#Mapping : allages->0,18plus->1,21plus->2
dat1.AgesAllowed.replace('allages',0,inplace=True)
dat1.AgesAllowed.replace('18plus',1,inplace=True)
dat1.AgesAllowed.replace('21plus',2,inplace=True)
dat1.AgesAllowed.unique()
# Out:
# array([ nan,   2.,   0.,   1.])

# %%
#Range of Alcohol
dat1.Alcohol.unique()
#Mapping : none->0, beer_and_wine->1,full_bar->2
dat1.Alcohol.replace('none',0,inplace=True)
dat1.Alcohol.replace('beer_and_wine',1,inplace=True)
dat1.Alcohol.replace('full_bar',2,inplace=True)
dat1.Alcohol.unique()
# Out:
# array([ nan,   0.,   1.,   2.])

# %%
#Mapping - count number of True Values - number of best nights in a week
for row in tqdm_notebook(dat1.BestNights):
    if type(row)==type(''):
        dat1.BestNights.replace(row,row.count('True'),inplace=True)   
dat1.BestNights.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   3.,   1.,   0.,   2.])

# %%
#Mapping - count number of True Values - number of types of ambiences it offers
for row in tqdm_notebook(dat1.Ambience):
    if type(row)==type(''):
        dat1.Ambience.replace(row,row.count('True'),inplace=True)   
dat1.Ambience.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   1.,   0.,   2.,   3.,   4.,   5.,   6.,   7.])

# %%
#Mapping - count number of True Values - number of types of parkings available
#eg- {'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False} has 1 type of parking
# and "{'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': True}" has 3
for row in tqdm_notebook(dat1.BusinessParking):
    if type(row)==type(''):
        dat1.BusinessParking.replace(row,row.count('True'),inplace=True)   
dat1.BusinessParking.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   1.,   0.,   2.,   3.,   4.,   5.])

# %%
for row in tqdm_notebook(dat1.GoodForMeal):
    if type(row)==type(''):
        dat1.GoodForMeal.replace(row,row.count('True'),inplace=True)   
dat1.GoodForMeal.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   3.,   0.,   2.,   1.,   4.,   6.,   5.])

# %%
for row in tqdm_notebook(dat1.HairSpecializesIn):
    if type(row)==type(''):
        dat1.HairSpecializesIn.replace(row,row.count('True'),inplace=True)   
dat1.HairSpecializesIn.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   6.,   5.])

# %%
for row in tqdm_notebook(dat1.Music):
    if type(row)==type(''):
        dat1.Music.replace(row,row.count('True'),inplace=True)   
dat1.Music.unique()
# Out:
# HBox(children=(IntProgress(value=0, max=8808), HTML(value='')))
# array([ nan,   0.,   1.,   2.,   3.,   4.,   5.,   6.])

# %%
#dat1.DietaryRestrictions.unique()
#7 types/combos of dietry restrictions. These are as follows -
dat1.DietaryRestrictions.replace("{'dairy-free': True, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}",0,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': False, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}",1,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': True, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': True, 'vegetarian': True}",2,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': False, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}",3,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': False, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': False}",4,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': True, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}",5,inplace=True)
dat1.DietaryRestrictions.replace("{'dairy-free': False, 'gluten-free': True, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': False}",6,inplace=True)
dat1.DietaryRestrictions.unique()
# Out:
# array([ nan,   0.,   1.,   2.,   3.,   4.,   5.,   6.])

# %%
dat1.fillna('Null', inplace=True)

# %%
dat1.to_csv('LasVegas_Restaurants_Temp.csv',',')
